# %%
import tensorflow as tf

# %%
x1 = tf.constant(5)

# %%
x1
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=5>

# %%
x2 = tf.constant(6)

# %%
x2
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=6>

# %%
tf.multiply(x1, x2)
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=30>

# %%
import pandas as pd
import numpy as np
import matplotlib 
matplotlib.use('nbagg')

import matplotlib.pyplot as plt
fig, axes = plt.subplots(4, 4)
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
df = pd.DataFrame(np.random.randn(1000, 4), columns=['A','B','C','D'])
pd.plotting.scatter_matrix(df, alpha=0.2)
# Out:
# <img src="data:image/png;base64,..." width="432">
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000284EB785748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000284EB43E948>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000284EB7EAF88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000284EBD439C8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000284EB8CA3C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000284EB77DD88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000284ED043908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000284EBC7BA08>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000284EBC6D608>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000284EB7A37C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000284EB821D48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000284EB870E08>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000284EBC3AF48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000284EBB3E088>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000284EB5E7188>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000284EB73A2C8>]],
#       dtype=object)
