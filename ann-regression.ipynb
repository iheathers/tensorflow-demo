# %%
import tensorflow as tf

# %%
import numpy as np

# %%
import matplotlib

# %%
matplotlib.use('nbagg')

# %%
import matplotlib.pyplot as plt

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
N = 1000

# %%
X = np.random.random((N, 2))*6 - 3

# %%
Y = np.cos(2*X[:, 0]) + np.cos(3*X[:, 1])

# %%
fig = plt.figure()

# %%
ax = fig.add_subplot(111, projection='3d')

# %%
ax.scatter(X[:, 0], X[:, 1], Y)

# %%
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(128, input_shape=(2, ), activation='relu'),
    tf.keras.layers.Dense(1)
])

# %%
opt = tf.keras.optimizers.Adam(0.01)

# %%
opt

# %%
model.compile(optimizer=opt, loss='mse')

# %%
r = model.fit(X, Y, epochs=100)
# Out:
# Train on 1000 samples
# Epoch 1/100
# 1000/1000 [==============================] - 1s 1ms/sample - loss: 1.0060
# Epoch 2/100
# 1000/1000 [==============================] - 0s 108us/sample - loss: 0.9338
# Epoch 3/100
# 1000/1000 [==============================] - 0s 72us/sample - loss: 0.9330
# Epoch 4/100
# 1000/1000 [==============================] - 0s 71us/sample - loss: 0.8915
# Epoch 5/100
# 1000/1000 [==============================] - 0s 76us/sample - loss: 0.8681
# Epoch 6/100
# 1000/1000 [==============================] - 0s 72us/sample - loss: 0.8643
# Epoch 7/100
# 1000/1000 [==============================] - 0s 72us/sample - loss: 0.7706
# Epoch 8/100
# 1000/1000 [==============================] - 0s 80us/sample - loss: 0.7115
# Epoch 9/100
# 1000/1000 [==============================] - 0s 80us/sample - loss: 0.6606
# Epoch 10/100
# 1000/1000 [==============================] - 0s 80us/sample - loss: 0.6090
# Epoch 11/100
# 1000/1000 [==============================] - 0s 80us/sample - loss: 0.5621
# Epoch 12/100
# 1000/1000 [==============================] - 0s 92us/sample - loss: 0.6015
# Epoch 13/100
# 1000/1000 [==============================] - 0s 84us/sample - loss: 0.5452
# Epoch 14/100
# 1000/1000 [==============================] - 0s 84us/sample - loss: 0.5829
# Epoch 15/100
# 1000/1000 [==============================] - 0s 68us/sample - loss: 0.5357
# Epoch 16/100
# 1000/1000 [==============================] - 0s 72us/sample - loss: 0.5149
# Epoch 17/100
# 1000/1000 [==============================] - 0s 76us/sample - loss: 0.5100
# Epoch 18/100
# 1000/1000 [==============================] - 0s 72us/sample - loss: 0.4985
# Epoch 19/100
# 1000/1000 [==============================] - 0s 72us/sample - loss: 0.4741
# Epoch 20/100
# 1000/1000 [==============================] - 0s 80us/sample - loss: 0.4267
# Epoch 21/100
# 1000/1000 [==============================] - 0s 72us/sample - loss: 0.4333
# Epoch 22/100
# 1000/1000 [==============================] - 0s 80us/sample - loss: 0.4062
# Epoch 23/100
# 1000/1000 [==============================] - 0s 68us/sample - loss: 0.3847
# Epoch 24/100
# 1000/1000 [==============================] - 0s 72us/sample - loss: 0.3510
# Epoch 25/100
# 1000/1000 [==============================] - 0s 88us/sample - loss: 0.3281
# Epoch 26/100
# 1000/1000 [==============================] - 0s 76us/sample - loss: 0.3233
# Epoch 27/100
# 1000/1000 [==============================] - 0s 84us/sample - loss: 0.3078
# Epoch 28/100
# 1000/1000 [==============================] - 0s 80us/sample - loss: 0.2947
# Epoch 29/100
# 1000/1000 [==============================] - 0s 84us/sample - loss: 0.2903
# Epoch 30/100
# 1000/1000 [==============================] - 0s 80us/sample - loss: 0.2705
# Epoch 31/100
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.2445
# Epoch 32/100
# 1000/1000 [==============================] - 0s 84us/sample - loss: 0.2263
# Epoch 33/100
# 1000/1000 [==============================] - 0s 84us/sample - loss: 0.2143
# Epoch 34/100
# 1000/1000 [==============================] - 0s 80us/sample - loss: 0.1996
# Epoch 35/100
# 1000/1000 [==============================] - 0s 84us/sample - loss: 0.2123
# Epoch 36/100
# 1000/1000 [==============================] - 0s 132us/sample - loss: 0.1924
# Epoch 37/100
# 1000/1000 [==============================] - 0s 96us/sample - loss: 0.1915
# Epoch 38/100
# 1000/1000 [==============================] - 0s 116us/sample - loss: 0.2022
# Epoch 39/100
# 1000/1000 [==============================] - 0s 96us/sample - loss: 0.1469
# Epoch 40/100
# 1000/1000 [==============================] - 0s 92us/sample - loss: 0.1307
# Epoch 41/100
# 1000/1000 [==============================] - 0s 92us/sample - loss: 0.1177
# Epoch 42/100
# 1000/1000 [==============================] - 0s 104us/sample - loss: 0.1259
# Epoch 43/100
# 1000/1000 [==============================] - 0s 104us/sample - loss: 0.0985
# Epoch 44/100
# 1000/1000 [==============================] - 0s 96us/sample - loss: 0.1163
# Epoch 45/100
# 1000/1000 [==============================] - 0s 104us/sample - loss: 0.0822
# Epoch 46/100
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0796
# Epoch 47/100
# 1000/1000 [==============================] - 0s 96us/sample - loss: 0.0603
# Epoch 48/100
# 1000/1000 [==============================] - 0s 108us/sample - loss: 0.0400
# Epoch 49/100
# 1000/1000 [==============================] - 0s 96us/sample - loss: 0.0310
# Epoch 50/100
# 1000/1000 [==============================] - 0s 100us/sample - loss: 0.0353
# Epoch 51/100
# 1000/1000 [==============================] - 0s 96us/sample - loss: 0.0317
# Epoch 52/100
# 1000/1000 [==============================] - 0s 104us/sample - loss: 0.0247
# Epoch 53/100
# 1000/1000 [==============================] - 0s 116us/sample - loss: 0.0187
# Epoch 54/100
# 1000/1000 [==============================] - 0s 92us/sample - loss: 0.0215
# Epoch 55/100
# 1000/1000 [==============================] - 0s 92us/sample - loss: 0.0148
# Epoch 56/100
# 1000/1000 [==============================] - 0s 92us/sample - loss: 0.0128
# Epoch 57/100
# 1000/1000 [==============================] - 0s 92us/sample - loss: 0.0143
# Epoch 58/100
# 1000/1000 [==============================] - 0s 96us/sample - loss: 0.0112
# Epoch 59/100
# 1000/1000 [==============================] - 0s 92us/sample - loss: 0.0135
# Epoch 60/100
# 1000/1000 [==============================] - 0s 92us/sample - loss: 0.0148
# Epoch 61/100
# 1000/1000 [==============================] - 0s 92us/sample - loss: 0.0147
# Epoch 62/100
# 1000/1000 [==============================] - 0s 76us/sample - loss: 0.0085
# Epoch 63/100
# 1000/1000 [==============================] - 0s 68us/sample - loss: 0.0102
# Epoch 64/100
# 1000/1000 [==============================] - 0s 73us/sample - loss: 0.0108
# Epoch 65/100
# 1000/1000 [==============================] - 0s 72us/sample - loss: 0.0070
# Epoch 66/100
# 1000/1000 [==============================] - 0s 68us/sample - loss: 0.0069
# Epoch 67/100
# 1000/1000 [==============================] - 0s 64us/sample - loss: 0.0091
# Epoch 68/100
# 1000/1000 [==============================] - 0s 68us/sample - loss: 0.0067
# Epoch 69/100
# 1000/1000 [==============================] - 0s 68us/sample - loss: 0.0157
# Epoch 70/100
# 1000/1000 [==============================] - 0s 64us/sample - loss: 0.0117
# Epoch 71/100
# 1000/1000 [==============================] - 0s 72us/sample - loss: 0.0077
# Epoch 72/100
# 1000/1000 [==============================] - 0s 60us/sample - loss: 0.0059
# Epoch 73/100
# 1000/1000 [==============================] - 0s 68us/sample - loss: 0.0060
# Epoch 74/100
# 1000/1000 [==============================] - 0s 64us/sample - loss: 0.0095
# Epoch 75/100
# 1000/1000 [==============================] - 0s 72us/sample - loss: 0.0082
# Epoch 76/100
# 1000/1000 [==============================] - 0s 72us/sample - loss: 0.0263
# Epoch 77/100
# 1000/1000 [==============================] - 0s 64us/sample - loss: 0.0268
# Epoch 78/100
# 1000/1000 [==============================] - 0s 68us/sample - loss: 0.0220
# Epoch 79/100
# 1000/1000 [==============================] - 0s 68us/sample - loss: 0.0100
# Epoch 80/100
# 1000/1000 [==============================] - 0s 77us/sample - loss: 0.0079
# Epoch 81/100
# 1000/1000 [==============================] - 0s 68us/sample - loss: 0.0092
# Epoch 82/100
# 1000/1000 [==============================] - 0s 68us/sample - loss: 0.0054
# Epoch 83/100
# 1000/1000 [==============================] - 0s 84us/sample - loss: 0.0073
# Epoch 84/100
# 1000/1000 [==============================] - 0s 80us/sample - loss: 0.0084
# Epoch 85/100
# 1000/1000 [==============================] - 0s 88us/sample - loss: 0.0055
# Epoch 86/100
# 1000/1000 [==============================] - 0s 88us/sample - loss: 0.0055
# Epoch 87/100
# 1000/1000 [==============================] - 0s 88us/sample - loss: 0.0048
# Epoch 88/100
# 1000/1000 [==============================] - 0s 84us/sample - loss: 0.0082
# Epoch 89/100
# 1000/1000 [==============================] - 0s 104us/sample - loss: 0.0233
# Epoch 90/100
# 1000/1000 [==============================] - 0s 68us/sample - loss: 0.0138
# Epoch 91/100
# 1000/1000 [==============================] - 0s 80us/sample - loss: 0.0480
# Epoch 92/100
# 1000/1000 [==============================] - 0s 73us/sample - loss: 0.0657
# Epoch 93/100
# 1000/1000 [==============================] - 0s 76us/sample - loss: 0.0121
# Epoch 94/100
# 1000/1000 [==============================] - 0s 76us/sample - loss: 0.0257
# Epoch 95/100
# 1000/1000 [==============================] - 0s 72us/sample - loss: 0.0276
# Epoch 96/100
# 1000/1000 [==============================] - 0s 72us/sample - loss: 0.0220
# Epoch 97/100
# 1000/1000 [==============================] - 0s 64us/sample - loss: 0.0126
# Epoch 98/100
# 1000/1000 [==============================] - 0s 64us/sample - loss: 0.0054
# Epoch 99/100
# 1000/1000 [==============================] - 0s 64us/sample - loss: 0.0055
# Epoch 100/100
# 1000/1000 [==============================] - 0s 64us/sample - loss: 0.0079

# %%
fig, ax = plt.subplots()

# %%
ax.plot(r.history['loss'], label='loss')

# %%
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig, ax = plt.subplots(projection='3d')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-139e9bf74e94> in <module>
# ----> 1 fig, ax = plt.subplots(projection='3d')
#
# ~\anaconda3\envs\deep-learning\lib\site-packages\matplotlib\pyplot.py in subplots(nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw, **fig_kw)
#    1207
#    1208     """
# -> 1209     fig = figure(**fig_kw)
#    1210     axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1211                        squeeze=squeeze, subplot_kw=subplot_kw,
#
# ~\anaconda3\envs\deep-learning\lib\site-packages\matplotlib\pyplot.py in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, clear, **kwargs)
#     543                                         frameon=frameon,
#     544                                         FigureClass=FigureClass,
# --> 545                                         **kwargs)
#     546
#     547         if figLabel:
#
# ~\anaconda3\envs\deep-learning\lib\site-packages\matplotlib\backend_bases.py in new_figure_manager(cls, num, *args, **kwargs)
#    3258         from matplotlib.figure import Figure
#    3259         fig_cls = kwargs.pop('FigureClass', Figure)
# -> 3260         fig = fig_cls(*args, **kwargs)
#    3261         return cls.new_figure_manager_given_figure(num, fig)
#    3262
#
# TypeError: __init__() got an unexpected keyword argument 'projection'

# %%
c
# Out:
# C:\Users\pshre\anaconda3\envs\deep-learning\lib\site-packages\matplotlib\collections.py:857: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig, ax = plt.subplots()
ax.(projection='3d')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-47-67a875d0680c> in <module>
#       1 fig, ax = plt.subplots()
# ----> 2 ax.add_subplot(projection='3d')
#
# AttributeError: 'AxesSubplot' object has no attribute 'add_subplot'

# %%
line = np.linspace(-3, 3, 50)

# %%
xx, yy = np.meshgrid(line, line)

# %%
xx
# Out:
# array([[-3.        , -2.87755102, -2.75510204, ...,  2.75510204,
#          2.87755102,  3.        ],
#        [-3.        , -2.87755102, -2.75510204, ...,  2.75510204,
#          2.87755102,  3.        ],
#        [-3.        , -2.87755102, -2.75510204, ...,  2.75510204,
#          2.87755102,  3.        ],
#        ...,
#        [-3.        , -2.87755102, -2.75510204, ...,  2.75510204,
#          2.87755102,  3.        ],
#        [-3.        , -2.87755102, -2.75510204, ...,  2.75510204,
#          2.87755102,  3.        ],
#        [-3.        , -2.87755102, -2.75510204, ...,  2.75510204,
#          2.87755102,  3.        ]])

# %%
Xgrid = np.vstack((xx.flatten(), yy.flatten())).T

# %%
Yhat = model.predict(Xgrid).flatten()

# %%
ax.plot_trisurf(Xgrid[:, 0], Xgrid[:,1], Yhat)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-45-1da705f208e7> in <module>
# ----> 1 ax.plot_trisurf(Xgrid[:, 0], Xgrid[:,1], Yhat)
#
# AttributeError: 'AxesSubplot' object has no attribute 'plot_trisurf'

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X[:,0], X[:,1], Y)

# surface plot
line = np.linspace(-3, 3, 50)
xx, yy = np.meshgrid(line, line)
Xgrid = np.vstack((xx.flatten(), yy.flatten())).T
Yhat = model.predict(Xgrid).flatten()
ax.plot_trisurf(Xgrid[:,0], Xgrid[:,1], Yhat, linewidth=0.2, antialiased=True)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X[:,0], X[:,1], Y)

# surface plot
line = np.linspace(-5, 5, 50)
xx, yy = np.meshgrid(line, line)
Xgrid = np.vstack((xx.flatten(), yy.flatten())).T
Yhat = model.predict(Xgrid).flatten()
ax.plot_trisurf(Xgrid[:,0], Xgrid[:,1], Yhat, linewidth=0.2, antialiased=True)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
